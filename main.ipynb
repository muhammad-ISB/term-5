# %%
import pandas as pd
df = pd.read_csv('Clean_Dataset.csv', index_col=False) 
df
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
interested_cols = ['airline', 'flight', 'source_city', 'departure_time', 'stops', 'arrival_time', 'destination_city', 'class']
for i in interested_cols:
    print(df[i].value_counts())
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: count, dtype: int64
# flight
# UK-706     3235
# UK-772     2741
# UK-720     2650
# UK-836     2542
# UK-822     2468
#            ...
# SG-9923       1
# 6E-6474       1
# 6E-865        1
# G8-705        1
# G8-107        1
# Name: count, Length: 1561, dtype: int64
# source_city
# Delhi        61343
# Mumbai       60896
# Bangalore    52061
# Kolkata      46347
# Hyderabad    40806
# Chennai      38700
# Name: count, dtype: int64
# departure_time
# Morning          71146
# Early_Morning    66790
# Evening          65102
# Night            48015
# Afternoon        47794
# Late_Night        1306
# Name: count, dtype: int64
# stops
# one            250863
# zero            36004
# two_or_more     13286
# Name: count, dtype: int64
# arrival_time
# Night            91538
# Evening          78323
# Morning          62735
# ...

# %%
df.airline.value_counts()
# Out:
# airline
# Vistara      127859
# Air_India     80892
# Indigo        43120
# GO_FIRST      23173
# AirAsia       16098
# SpiceJet       9011
# Name: count, dtype: int64

# %%
df.source_city.value_counts()
# Out:
# source_city
# Delhi        61343
# Mumbai       60896
# Bangalore    52061
# Kolkata      46347
# Hyderabad    40806
# Chennai      38700
# Name: count, dtype: int64

# %%
cols_2_unique = [col for col in df.columns if df[col].nunique() == 2]
cols_2_unique
# Out:
# ['class']

# %%
describe_cols = ['duration', 'days_left', 'price']
for d in describe_cols:
    print(df[d].describe())
# Out:
# count    300153.000000
# mean         12.221021
# std           7.191997
# min           0.830000
# 25%           6.830000
# 50%          11.250000
# 75%          16.170000
# max          49.830000
# Name: duration, dtype: float64
# count    300153.000000
# mean         26.004751
# std          13.561004
# min           1.000000
# 25%          15.000000
# 50%          26.000000
# 75%          38.000000
# max          49.000000
# Name: days_left, dtype: float64
# count    300153.000000
# mean      20889.660523
# std       22697.767366
# min        1105.000000
# 25%        4783.000000
# 50%        7425.000000
# 75%       42521.000000
# max      123071.000000
# Name: price, dtype: float64

# %% [markdown]
# ## Preprocessing

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'airline', 'flight', 'source_city', 'departure_time',
#        'stops', 'arrival_time', 'destination_city', 'class', 'duration',
#        'days_left', 'price'],
#       dtype='object')
